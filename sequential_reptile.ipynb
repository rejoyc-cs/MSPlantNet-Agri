# %%
import os

os.environ["KERAS_BACKEND"] = "tensorflow"

import keras
from keras import layers

import matplotlib.pyplot as plt
import numpy as np
import random
import tensorflow as tf
import tensorflow_datasets as tfds

# %%
# !unzip '/content/drive/MyDrive/ACPS/Common_diseases.zip'
# Out:
# Archive:  /content/drive/MyDrive/ACPS/Common_diseases.zip
#    creating: Common_diseases/
#    creating: Common_diseases/Tar_Spot/
#   inflating: Common_diseases/Tar_Spot/20230628-tarspot-1-720x400.webp
#   inflating: Common_diseases/Tar_Spot/9883630384_504442d19b_b.jpg
#   inflating: Common_diseases/Tar_Spot/0327T1-1602-1800x1012.jpg
#   inflating: Common_diseases/Tar_Spot/220825_tarspot_md.png
#   inflating: Common_diseases/Tar_Spot/93352_small.jpg
#   inflating: Common_diseases/Tar_Spot/yellow-maple-leaves-with-black-white-spots-fungal-disease-tar-spot-maple-leaf_716625-942.avif
#   inflating: Common_diseases/Tar_Spot/tarspont_lg.500x0.jpg
#   inflating: Common_diseases/Tar_Spot/12.-tar-spot-on-norway-maple.jpg
#   inflating: Common_diseases/Tar_Spot/4cedb523df8ad.image.jpg
#   inflating: Common_diseases/Tar_Spot/unnamed.jpg
#   inflating: Common_diseases/Tar_Spot/Tar spot severity.png
#   inflating: Common_diseases/Tar_Spot/Tarspot.jpg
#   inflating: Common_diseases/Tar_Spot/Corn tar spot 2.jpg
#   inflating: Common_diseases/Tar_Spot/tar-spot.jpg
#   inflating: Common_diseases/Tar_Spot/tar-spot-scattered-structures.jpg
#   inflating: Common_diseases/Tar_Spot/yellow-maple-leaves-with-black-white-spots-fungal-disease-tar-spot-maple-leaf_716625-700.avif
#   inflating: Common_diseases/Tar_Spot/93353_medium.jpg
#   inflating: Common_diseases/Tar_Spot/e9ec8d27-a8a3-4c77-b24f-e17af74cabaf-8d9ac51.jpg
#   inflating: Common_diseases/Tar_Spot/field-maple-leaves-autumn-infected-tar-spot-1296719.jpg.webp
#   inflating: Common_diseases/Tar_Spot/IT-blog-section-2021-Aug-maple-tar-spot-on-many-leaves.jpg
#   inflating: Common_diseases/Tar_Spot/16-01109-Maple_01.jpg
#   inflating: Common_diseases/Tar_Spot/TarSpot.png
#   inflating: Common_diseases/Tar_Spot/tar-spot-of-maple-1_edit-1920x1440-c-default.jpg
#   inflating: Common_diseases/Tar_Spot/tar-spot-corn-malvick.jpg
#   inflating: Common_diseases/Tar_Spot/wpr-meiller-weather-plantdiseases-tarspot.jpg
#   inflating: Common_diseases/Tar_Spot/Tar_spot_fungus_(76170).jpg
#    creating: Common_diseases/Golden_canker/
#   inflating: Common_diseases/Golden_canker/200402011GoldenCanker2.jpg
#   inflating: Common_diseases/Golden_canker/GIB7xaPXQAA8pDt.jpg
#   inflating: Common_diseases/Golden_canker/76012_small.jpg
#   inflating: Common_diseases/Golden_canker/76013_medium.jpg
#   inflating: Common_diseases/Golden_canker/DXZjq2lXUAAYnj5.jpg
#   inflating: Common_diseases/Golden_canker/goldencanker1_600px.jpg
#   inflating: Common_diseases/Golden_canker/golden-canker-pagoda-dogwood-stem.jpg
#   inflating: Common_diseases/Golden_canker/golden-canker-branch-tip.jpg
#   inflating: Common_diseases/Golden_canker/golden_canker_of_pagoda_dogwood.jpg
#   inflating: Common_diseases/Golden_canker/large.jpeg
#   inflating: Common_diseases/Golden_canker/Golden_canker.png
#    creating: Common_diseases/Black_knot/
#   inflating: Common_diseases/Black_knot/black-knot-of-plum-and-cherry_10_168027029.jpeg
#   inflating: Common_diseases/Black_knot/Black-Knot-Fungus-1200x667.webp
#   inflating: Common_diseases/Black_knot/Black-Knot-Disease (1).jpg
#   inflating: Common_diseases/Black_knot/Black-Knot-Disease-photo-by-Anthony-Dean.webp
#   inflating: Common_diseases/Black_knot/BlackKnot-TenCommonPlantDiseases.png
#   inflating: Common_diseases/Black_knot/Rayzor-blog-featured-2022-Nov-black-knot.webp
#   inflating: Common_diseases/Black_knot/unnamed.jpg
#   inflating: Common_diseases/Black_knot/BlackKnot01sm.jpg
#   inflating: Common_diseases/Black_knot/cs-blackknot.-full.jpg
#   inflating: Common_diseases/Black_knot/HGIC_trees_blackknot_16x9.jpg
#   inflating: Common_diseases/Black_knot/Black-Knot-Disease-Example-768x1024.jpg
#   inflating: Common_diseases/Black_knot/Black_knot_growth1.jpg
#   inflating: Common_diseases/Black_knot/Black_Knot60.jpg
#   inflating: Common_diseases/Black_knot/black-knot-disease.webp
#   inflating: Common_diseases/Black_knot/20140730_100513-300x200.jpg
#   inflating: Common_diseases/Black_knot/HGIC_trees_black_knot_cherry_DC_400.jpg
#   inflating: Common_diseases/Black_knot/BlackKnot-withleaves.jpg
#   inflating: Common_diseases/Black_knot/Rayzor-blog-section-2022-Nov-black-knot-cherry.webp
#   inflating: Common_diseases/Black_knot/IMG_3712-edit-resized.jpg
#   inflating: Common_diseases/Black_knot/BlackKnot-roundknot.jpg
#   inflating: Common_diseases/Black_knot/knot3.jpg
#   inflating: Common_diseases/Black_knot/large.jpg
#   inflating: Common_diseases/Black_knot/P9UZqDx8Di9jsQ2q7KRrnK.jpg
#   inflating: Common_diseases/Black_knot/BlackKnot-old.jpg
#   inflating: Common_diseases/Black_knot/blacknot1.jpg
#   inflating: Common_diseases/Black_knot/black-knot (2).jpg
#   inflating: Common_diseases/Black_knot/f89QAxy2bwsiLDBTU4A8ie.jpg
#   inflating: Common_diseases/Black_knot/Black-Knot (3).jpg
#   inflating: Common_diseases/Black_knot/Figure-1-1-1152x1536.jpg
#   inflating: Common_diseases/Black_knot/BlackKnot_early-and-late-stage-1920x1475.12195122-c-default.jpg
#   inflating: Common_diseases/Black_knot/original.jpg
#   inflating: Common_diseases/Black_knot/black-knot-fungus.webp
#   inflating: Common_diseases/Black_knot/black-knot-300k.jpg
#   inflating: Common_diseases/Black_knot/e17d17fb-3a2f-482d-a8b1-57aca5b4ab05.jpg
#   inflating: Common_diseases/Black_knot/black-knot-disease.jpg
#   inflating: Common_diseases/Black_knot/black-knot (1).jpg
#   inflating: Common_diseases/Black_knot/black-knot-1920x854.180734856-c-default.jpg
#   inflating: Common_diseases/Black_knot/Black_Knot.jpg
#   inflating: Common_diseases/Black_knot/black-knot.jpg
#   inflating: Common_diseases/Black_knot/Apiosporina-morbosa-cover.png
#   inflating: Common_diseases/Black_knot/knot3close.jpg
#    creating: Common_diseases/Elderberry_rust/
#   inflating: Common_diseases/Elderberry_rust/5RLH6RRHXRALZZTLLZNLIZ1LXZOL2RKHERCLSZCLIZOLMZLHPRVLYLWLIRTZ8ROZXRFZ7R0HXRPLLZWLKRWL3LOZFL.jpg
#   inflating: Common_diseases/Elderberry_rust/20-06-06.jpg
#   inflating: Common_diseases/Elderberry_rust/30BQZSVQ108K6K0KDK4KUKHKWK5KOKMKY0GK304Q9KLK1KGKUKGQO0SKC0EQC0RK6KPQWKQKV0GQNK6QB08QO0PQD0.jpg
#   inflating: Common_diseases/Elderberry_rust/33-Figure2-1.png
#   inflating: Common_diseases/Elderberry_rust/14304854510_ac794edb62_q.jpg
#   inflating: Common_diseases/Elderberry_rust/unnamed (2).jpg
#   inflating: Common_diseases/Elderberry_rust/Screenshot 2024-03-30 030013.png
#   inflating: Common_diseases/Elderberry_rust/ipm1036_fig01c.jpg
#   inflating: Common_diseases/Elderberry_rust/banana-growth1_med_hr.jpeg
#   inflating: Common_diseases/Elderberry_rust/ipm1037_fig13.jpg
#   inflating: Common_diseases/Elderberry_rust/ipm1036_fig03a.jpg
#   inflating: Common_diseases/Elderberry_rust/Screenshot 2024-03-30 030131.png
#   inflating: Common_diseases/Elderberry_rust/big_rust.jpg
#   inflating: Common_diseases/Elderberry_rust/50049381622_10b0742a89_b.jpg
#   inflating: Common_diseases/Elderberry_rust/ElderberryRust-TenCommonPlantDiseases.png
#   inflating: Common_diseases/Elderberry_rust/Screenshot 2024-03-30 025949.png
#   inflating: Common_diseases/Elderberry_rust/OH8H1H7H1HPHFH6HZR2HHRUHFH8L9Z9H1ZEHUZEHNZIL9Z5LRR2HWZPH9ZGL9Z8LBZ4LUZ6HRR5L1Z4L.jpg
#   inflating: Common_diseases/Elderberry_rust/unnamed (1).jpg
#   inflating: Common_diseases/Elderberry_rust/flowerLoss.jpg
#   inflating: Common_diseases/Elderberry_rust/unnamed.jpg
#   inflating: Common_diseases/Elderberry_rust/ipm1036_fig01b.jpg
#   inflating: Common_diseases/Elderberry_rust/20-06-07.jpg
#   inflating: Common_diseases/Elderberry_rust/sambucus rust 5 Mo 6-10-16 S.jpg
#   inflating: Common_diseases/Elderberry_rust/rustSymptoms.jpg
#    creating: Common_diseases/Dog_vomit_slime_mold/
#   inflating: Common_diseases/Dog_vomit_slime_mold/dogvomitslimemold3.jpg
#   inflating: Common_diseases/Dog_vomit_slime_mold/1573335-PPT.jpg
#   inflating: Common_diseases/Dog_vomit_slime_mold/dogvomitslimemold6.webp
#   inflating: Common_diseases/Dog_vomit_slime_mold/dogvomitslimemold4.webp
#   inflating: Common_diseases/Dog_vomit_slime_mold/Those-Mysterious-Molds-Part-1-The-Blob.jpg
#   inflating: Common_diseases/Dog_vomit_slime_mold/img_4743.webp
#   inflating: Common_diseases/Dog_vomit_slime_mold/5454655-PPT_0.jpg
#   inflating: Common_diseases/Dog_vomit_slime_mold/img_4736.webp
#   inflating: Common_diseases/Dog_vomit_slime_mold/dogvomitslimemold5.webp
#   inflating: Common_diseases/Dog_vomit_slime_mold/VYeSwjpoiZn9X5GYRBfmAh.png
#   inflating: Common_diseases/Dog_vomit_slime_mold/dogvomitslimemold2.webp
#   inflating: Common_diseases/Dog_vomit_slime_mold/img_6958.webp
#   inflating: Common_diseases/Dog_vomit_slime_mold/slime-mold-2.jpg
#   inflating: Common_diseases/Dog_vomit_slime_mold/DogVomitSlimeMold-TenCommonPlantDiseases.png
#   inflating: Common_diseases/Dog_vomit_slime_mold/dogvomitslimemold4.jpg
#   inflating: Common_diseases/Dog_vomit_slime_mold/slime-mold-2 (1).jpg
#   inflating: Common_diseases/Dog_vomit_slime_mold/slime-mold2.jpg
#   inflating: Common_diseases/Dog_vomit_slime_mold/img_4740.webp
#   inflating: Common_diseases/Dog_vomit_slime_mold/o_1gefrj9jh1iflhmbqh410nv15fv1m.jpg
#   inflating: Common_diseases/Dog_vomit_slime_mold/79813.jpg
#   inflating: Common_diseases/Dog_vomit_slime_mold/o_1g68pju37dba18m716vo1fth1jcck.jpg
#   inflating: Common_diseases/Dog_vomit_slime_mold/large (1).jpg
#   inflating: Common_diseases/Dog_vomit_slime_mold/dog-vomit-scaled.jpg
#   inflating: Common_diseases/Dog_vomit_slime_mold/Getty-517026943-Resize-Recolor-DH-FHM-Yellow-Dog-Vomit-Mold-and-What-it-Means.jpg
#   inflating: Common_diseases/Dog_vomit_slime_mold/2188456193_de74bf907c_b.jpg
#   inflating: Common_diseases/Dog_vomit_slime_mold/iStock-182895904-what-is-slime-mold.webp
#   inflating: Common_diseases/Dog_vomit_slime_mold/I0000lf2FTOCw.mg.jpg
#   inflating: Common_diseases/Dog_vomit_slime_mold/original.jpg
#   inflating: Common_diseases/Dog_vomit_slime_mold/DogVomitSmall.png
#   inflating: Common_diseases/Dog_vomit_slime_mold/large.jpg
#   inflating: Common_diseases/Dog_vomit_slime_mold/img_8769.jpg
#   inflating: Common_diseases/Dog_vomit_slime_mold/dog_vomit_slime_mold_liquid_closeup_09-17-14 (1).webp
#   inflating: Common_diseases/Dog_vomit_slime_mold/identifying-and-controlling-dog-vomit-fungus-2539510-01-c272b7f26e694a5b97d1472519214cb3.jpg
#   inflating: Common_diseases/Dog_vomit_slime_mold/dog_vomit_slime_mold_liquid_closeup_09-17-14.webp
#   inflating: Common_diseases/Dog_vomit_slime_mold/iStock-518732516-dog-vomit-slime-mold.webp
#   inflating: Common_diseases/Dog_vomit_slime_mold/6736657420124160.jpeg
#   inflating: Common_diseases/Dog_vomit_slime_mold/080520_slime-molds-dog-vomit-slime-mold-(fuligo-septica).jpg
#   inflating: Common_diseases/Dog_vomit_slime_mold/identifying-and-controlling-dog-vomit-fungus-2539510-hero-240cdb0c828144fb8e4d0d761ec34df9.jpg
#   inflating: Common_diseases/Dog_vomit_slime_mold/arwrkss042i81.webp
#   inflating: Common_diseases/Dog_vomit_slime_mold/5cb0b60888943.image.jpg
#   inflating: Common_diseases/Dog_vomit_slime_mold/Fuligo_septica_-_Gelbe_Lohblüte_-_Hexenbutter_-_02.jpg
#    creating: Common_diseases/Sooty Mold/
#   inflating: Common_diseases/Sooty Mold/Sooty_mould_on_trachelospermum.jpg
#   inflating: Common_diseases/Sooty Mold/2b9bcad6-585c-412e-894d-9b093b668a56.png
#   inflating: Common_diseases/Sooty Mold/sooty-mold2.webp
#   inflating: Common_diseases/Sooty Mold/sootymold.png
#   inflating: Common_diseases/Sooty Mold/sooty_mould_coconut_5950.jpg
#   inflating: Common_diseases/Sooty Mold/sooty-mold1.jpg
#   inflating: Common_diseases/Sooty Mold/fumagina7DNF.jpg
#   inflating: Common_diseases/Sooty Mold/capnci02.jpeg
#   inflating: Common_diseases/Sooty Mold/gv6UYbgXdnn7pY7xSMhiRV.jpg
#   inflating: Common_diseases/Sooty Mold/sooty_mold_2.JPG
#   inflating: Common_diseases/Sooty Mold/16688570510_86812b308f_b.jpg
#   inflating: Common_diseases/Sooty Mold/GumboPests_17.jpg
#   inflating: Common_diseases/Sooty Mold/unnamed.jpg
#   inflating: Common_diseases/Sooty Mold/pe0doxal3vsz.webp
#   inflating: Common_diseases/Sooty Mold/sooty-mold.webp
#   inflating: Common_diseases/Sooty Mold/64f9984ef1f55b97a36cc4ee_Control Sooty Mould in plants and vegetables-Article Image.webp
#   inflating: Common_diseases/Sooty Mold/image1_9.jpeg
#   inflating: Common_diseases/Sooty Mold/Black-sooty-mold-on-crapemyrtle-leaves.png
#   inflating: Common_diseases/Sooty Mold/sootymouldtetere5804.jpg
#   inflating: Common_diseases/Sooty Mold/moldylraf-225x300.jpg
#   inflating: Common_diseases/Sooty Mold/shutterstock_1180174114_1500x.webp
#   inflating: Common_diseases/Sooty Mold/sooty-mould-on-citrus-leaves-cropped-lr.jpg
#   inflating: Common_diseases/Sooty Mold/black-sooty-mold-crepe-myrtle-2.jpg
#   inflating: Common_diseases/Sooty Mold/images.jpeg
#   inflating: Common_diseases/Sooty Mold/2.jpg
#   inflating: Common_diseases/Sooty Mold/Sooty-Mold.jpg
#   inflating: Common_diseases/Sooty Mold/Aphids-attacking-leaves-and-spreading-sooty-mold-fungus.jpg
#   inflating: Common_diseases/Sooty Mold/RHS_SCN0000502sootymould_597736.JPG
#   inflating: Common_diseases/Sooty Mold/SootyMold_361x240.webp
#   inflating: Common_diseases/Sooty Mold/sooty-mold-treatment.jpg
#   inflating: Common_diseases/Sooty Mold/20141123-2-pests-S.jpg
#   inflating: Common_diseases/Sooty Mold/daves farm 017.JPG
#   inflating: Common_diseases/Sooty Mold/SootyMold_comp-min.jpg
#   inflating: Common_diseases/Sooty Mold/sooty-mold(1).jpg
#   inflating: Common_diseases/Sooty Mold/droppedImage-80.jpg
#   inflating: Common_diseases/Sooty Mold/pr-tn-disease-citrus-sooty-mould.webp
#   inflating: Common_diseases/Sooty Mold/12517743_l-123stock.jpg
#   inflating: Common_diseases/Sooty Mold/silver-maple-tree-sooty-mold-left-and-lichens-right.jpg
#   inflating: Common_diseases/Sooty Mold/1200px-Scale_and_sooty_mold_on_a_Eucalyptus_tree.jpg
#   inflating: Common_diseases/Sooty Mold/black-dust-on-leaves.webp
#   inflating: Common_diseases/Sooty Mold/crop_sooty_mold_california_laurel_joseph_obrien_usda_forest_service_bugwood.jpg
#   inflating: Common_diseases/Sooty Mold/sooty-mold-holly-2020.jpg
#    creating: Common_diseases/peach_leaf_curl/
#   inflating: Common_diseases/peach_leaf_curl/peach-leaf-curl-leaves-1920x986.358381503-c-default.jpg
#   inflating: Common_diseases/peach_leaf_curl/peach-leaf-curl-1.jpg
#   inflating: Common_diseases/peach_leaf_curl/Peach-tree-with-leaf-curl.jpg
#   inflating: Common_diseases/peach_leaf_curl/REALDIRT-01-2.webp
#   inflating: Common_diseases/peach_leaf_curl/large.jpeg
#   inflating: Common_diseases/peach_leaf_curl/istockphoto-1481901409-612x612.jpg
#   inflating: Common_diseases/peach_leaf_curl/peach-leaf-curl-taphrina-deformans-branch-disease-65979200.webp
#   inflating: Common_diseases/peach_leaf_curl/original.jpeg
#   inflating: Common_diseases/peach_leaf_curl/taphrina-deformans.webp
#   inflating: Common_diseases/peach_leaf_curl/360_F_439493873_B3GyuZnVpjbDSBUPIQfWPUiBKiNytMPu.jpg
#   inflating: Common_diseases/peach_leaf_curl/depositphotos_479027884-stock-photo-peach-leaf-curl-fruit-tree.webp
#   inflating: Common_diseases/peach_leaf_curl/qpy0twyejo291.webp
#   inflating: Common_diseases/peach_leaf_curl/TAPHRINA-DEFORMANS-NEVAL.jpg
#   inflating: Common_diseases/peach_leaf_curl/peach-leaf-curl1.webp
#   inflating: Common_diseases/peach_leaf_curl/peach-leaf-curl1.jpg
#   inflating: Common_diseases/peach_leaf_curl/plc-spores-close_zoom.jpg
#   inflating: Common_diseases/peach_leaf_curl/peach-leaf-curl.webp
#   inflating: Common_diseases/peach_leaf_curl/98720_original.jpg
#   inflating: Common_diseases/peach_leaf_curl/peach-tree-leaves-curling.jpg
#   inflating: Common_diseases/peach_leaf_curl/peach-leaf-curl1-5x5.jpg
#   inflating: Common_diseases/peach_leaf_curl/32624427_l-123stock.jpg
#   inflating: Common_diseases/peach_leaf_curl/peach-leaf-curl-Scot-Nelson-flickr-W1200.jpg
#   inflating: Common_diseases/peach_leaf_curl/peach-leaf-curl(1).jpg
#   inflating: Common_diseases/peach_leaf_curl/leaf-curl-disease.webp
#   inflating: Common_diseases/peach_leaf_curl/Taphrina_deformans_1.jpg
#   inflating: Common_diseases/peach_leaf_curl/peach-leaf-curl.JPG
#   inflating: Common_diseases/peach_leaf_curl/Screen+Shot+2021-03-29+at+4.05.50+PM.png
#    creating: Common_diseases/Gymnosporangium_Rusts/
#   inflating: Common_diseases/Gymnosporangium_Rusts/car_fruit_2.png
#   inflating: Common_diseases/Gymnosporangium_Rusts/5368594.jpg
#   inflating: Common_diseases/Gymnosporangium_Rusts/Rust_Romes_.jpeg
#   inflating: Common_diseases/Gymnosporangium_Rusts/CAR_LG.jpg
#   inflating: Common_diseases/Gymnosporangium_Rusts/car-apple1.jpg
#   inflating: Common_diseases/Gymnosporangium_Rusts/spots-Orange-cedar-apple-rust-disease-apple-leaf.webp
#   inflating: Common_diseases/Gymnosporangium_Rusts/RUST.png
#   inflating: Common_diseases/Gymnosporangium_Rusts/4e02f61b7878cb3ad70445141f72c224.jpg
#   inflating: Common_diseases/Gymnosporangium_Rusts/Cedar-Apple_Rust_Aecia_on_Callery_Pear_3-23-21.jpg
#   inflating: Common_diseases/Gymnosporangium_Rusts/RR9HFH9HHRNH3H7H8ZXHOHXHCHXH2ZZLGZMHAH0LAHMHEZ5HDHUHAZ2HBHXH1HXH1H7H2Z8HOHIH8Z.jpg
#   inflating: Common_diseases/Gymnosporangium_Rusts/CedarApple_Rust169.jpg
#   inflating: Common_diseases/Gymnosporangium_Rusts/car-leaf.jpg
#   inflating: Common_diseases/Gymnosporangium_Rusts/car-apple9.jpg
#   inflating: Common_diseases/Gymnosporangium_Rusts/Cedar-Apple-Rust.jpg
#   inflating: Common_diseases/Gymnosporangium_Rusts/153927_medium.jpg
#   inflating: Common_diseases/Gymnosporangium_Rusts/DSCN3002-1024x768.webp
#   inflating: Common_diseases/Gymnosporangium_Rusts/Cedar-apple_rust_2.jpg
#   inflating: Common_diseases/Gymnosporangium_Rusts/Gymnosparangium_juniperi-virginianae_23A_lg.jpg
#   inflating: Common_diseases/Gymnosporangium_Rusts/2-pyridia-lg.jpg
#   inflating: Common_diseases/Gymnosporangium_Rusts/5028059.jpg
#   inflating: Common_diseases/Gymnosporangium_Rusts/emergin-horns-1vfhori.jpg
#   inflating: Common_diseases/Gymnosporangium_Rusts/car.jpg
#   inflating: Common_diseases/Gymnosporangium_Rusts/unnamed.jpg
#   inflating: Common_diseases/Gymnosporangium_Rusts/1200px-Gymnosporangium_juniperii_telial_form.jpg
#   inflating: Common_diseases/Gymnosporangium_Rusts/cedar-apple_fig2.jpg
#   inflating: Common_diseases/Gymnosporangium_Rusts/large.jpg
#   inflating: Common_diseases/Gymnosporangium_Rusts/AdobeStock_147196252-scaled.jpeg
#   inflating: Common_diseases/Gymnosporangium_Rusts/cedar-apple-rust-gymnosporangium-juniperi-virginianae-ftimg.jpg
#   inflating: Common_diseases/Gymnosporangium_Rusts/Gymnosparangium_juniperi-virginianae_23D_lg.jpg
#   inflating: Common_diseases/Gymnosporangium_Rusts/sam_droege_inat_1444596361-5f0f5948de621.jpg
#   inflating: Common_diseases/Gymnosporangium_Rusts/1234146.jpg
#   inflating: Common_diseases/Gymnosporangium_Rusts/Gymnosparangium_juniperi-virginianae_23C_lg.jpg
#   inflating: Common_diseases/Gymnosporangium_Rusts/gymnosporangium_rust_on_amelanchier_leaf_infection_sm.jpg
#   inflating: Common_diseases/Gymnosporangium_Rusts/Gymnosporangium_globosum.jpg
#   inflating: Common_diseases/Gymnosporangium_Rusts/CedarAppleRust_apple.png
#   inflating: Common_diseases/Gymnosporangium_Rusts/gymnosporangium-crataegus-jbm003082_0.jpg
#   inflating: Common_diseases/Gymnosporangium_Rusts/Gymnosporangium_sabinae_om_Pyrus_leave.jpg
#   inflating: Common_diseases/Gymnosporangium_Rusts/gymnosporangium_rust_on_amelanchier_leaf_infection_2_sm.jpg
#   inflating: Common_diseases/Gymnosporangium_Rusts/cedar-apple-rust_fig-3.jpg
#   inflating: Common_diseases/Gymnosporangium_Rusts/CedarAppleRust_juniper.png
#   inflating: Common_diseases/Gymnosporangium_Rusts/cedar-apple_fig1.jpg
#    creating: Common_diseases/Chlorosis/
#   inflating: Common_diseases/Chlorosis/Chlorosis-Cinnamomum_camphora_mineral_deficiency_LR.jpg
#   inflating: Common_diseases/Chlorosis/maple_with_manganese_chlorosis.jpg
#   inflating: Common_diseases/Chlorosis/fig1.jpg
#   inflating: Common_diseases/Chlorosis/CHLOROSIS-HOW-TO-FIX-IT.jpg
#   inflating: Common_diseases/Chlorosis/main-qimg-076ccc9d6effbae7c5ce76fc8e57b788-lq.jpeg
#   inflating: Common_diseases/Chlorosis/TP-2019061002.jpeg
#   inflating: Common_diseases/Chlorosis/chlorosis_maple-224x300.jpg
#   inflating: Common_diseases/Chlorosis/4.1-Summer-2020-Chlorosis-The-Unhealthy-Yellow-Chlorosis-pic.jpg
#   inflating: Common_diseases/Chlorosis/tocv on tomato ant22 dscn0293.jpg
#   inflating: Common_diseases/Chlorosis/P1010120.JPG
#   inflating: Common_diseases/Chlorosis/ironchlorosis.jpg
#   inflating: Common_diseases/Chlorosis/IronChlorosis_460x@2x.webp
#   inflating: Common_diseases/Chlorosis/image006.jpg
#   inflating: Common_diseases/Chlorosis/Raspberry_vein_chlorosis_virus_NT5_(2).jpg
#   inflating: Common_diseases/Chlorosis/imag3852.jpg
#   inflating: Common_diseases/Chlorosis/Iron-Chlorosis-in-Hydrangea-feature.jpg
#   inflating: Common_diseases/Chlorosis/Chlorosis-Maple-Leaf-web.jpg
#   inflating: Common_diseases/Chlorosis/Iron_Chlorosis2257.jpg
#   inflating: Common_diseases/Chlorosis/istockphoto-539088920-612x612.jpg
#   inflating: Common_diseases/Chlorosis/iron_chlorosis_1200x1200.webp
#   inflating: Common_diseases/Chlorosis/chloroseferrique3-768x1024.jpg
#   inflating: Common_diseases/Chlorosis/Typical-pattern-of-chlorosis-observed-in-the-interveinal-regions-of-mature-leaves-from.png
#   inflating: Common_diseases/Chlorosis/jHvVHByfvPbuQEbQeVPGrY.jpg
#   inflating: Common_diseases/Chlorosis/how-do-i-help-this-chlorotic-tree-v0-x911jcwhm4cb1.jpg
#   inflating: Common_diseases/Chlorosis/3.jpg
#   inflating: Common_diseases/Chlorosis/Chlorosis-Is-it-Iron-Deficiency.webp
#   inflating: Common_diseases/Chlorosis/yellowleaves.jpg
#   inflating: Common_diseases/Chlorosis/pest-and-disease_chlorosis_sideimage_608x341.webp
#   inflating: Common_diseases/Chlorosis/chlorosis-leaf-interveinal-1.jpg
#   inflating: Common_diseases/Chlorosis/ironchlorosis-dogwood.jpg
#   inflating: Common_diseases/Chlorosis/Difference-Between-Chlorosis-and-Necrosis_Figure-1.webp
#   inflating: Common_diseases/Chlorosis/Iron-Chlorosis-yellow-leaves-scaled-1.jpg
#   inflating: Common_diseases/Chlorosis/pb_chlorosebekaempfung_sq-1.jpg
#   inflating: Common_diseases/Chlorosis/IT-cholorosis-header.jpg
#   inflating: Common_diseases/Chlorosis/chlorosus.jpg
#   inflating: Common_diseases/Chlorosis/Chlorosis_birchleaf.jpg
#   inflating: Common_diseases/Chlorosis/GR-ChlorosisConcordLeavesDavenport.jpg
#   inflating: Common_diseases/Chlorosis/How-to-SpotTreat-and-Prevent-Chlorosis.jpg
#   inflating: Common_diseases/Chlorosis/chlorosis-leaf.webp
#   inflating: Common_diseases/Chlorosis/chlorosis-1920x1440-c-default.jpg
#   inflating: Common_diseases/Chlorosis/chlorosis-leaf-interveinal-3.jpg
#   inflating: Common_diseases/Chlorosis/IDC_DMueller_03-1300x1733.jpg
#   inflating: Common_diseases/Chlorosis/original_06.PNG
#   inflating: Common_diseases/Chlorosis/ironchlorosis-maple2.jpg
#   inflating: Common_diseases/Chlorosis/maple-UST.jpg
#   inflating: Common_diseases/Chlorosis/severe-chlorosis-1920x1493.56446371-c-default.jpg
#   inflating: Common_diseases/Chlorosis/west chlorosis.jpg
#    creating: Common_diseases/Powdery Mildew/
#   inflating: Common_diseases/Powdery Mildew/mildew.webp
#   inflating: Common_diseases/Powdery Mildew/powdery_mildew_pumpkin_aiyura_6155.jpg
#   inflating: Common_diseases/Powdery Mildew/powdery-mildew-elise-dando-4.webp
#   inflating: Common_diseases/Powdery Mildew/3R5qa49DSELXxeXdutmPXG.jpg
#   inflating: Common_diseases/Powdery Mildew/intro-1696512134.jpg
#   inflating: Common_diseases/Powdery Mildew/csm_Powdery_mildew_tomato_1_8b7df6c243.webp
#   inflating: Common_diseases/Powdery Mildew/cucumber-powdery-mildew.jpg
#   inflating: Common_diseases/Powdery Mildew/11fd6d2c-f5fe-4128-ba6d-ce0873785493-4cbf7e8.jpg
#   inflating: Common_diseases/Powdery Mildew/Powdery-Mildew-Pumpkin-leaf.jpg
#   inflating: Common_diseases/Powdery Mildew/powdery-mildew-3-scaled.jpg
#   inflating: Common_diseases/Powdery Mildew/powdery mildew.jpg
#   inflating: Common_diseases/Powdery Mildew/plant-disease-mildew.webp
#   inflating: Common_diseases/Powdery Mildew/EarlyStagePowderyMildew_PAXIT025-1920x1440-c-default.jpg
#   inflating: Common_diseases/Powdery Mildew/zucchini-powdery-mildew.jpg
#   inflating: Common_diseases/Powdery Mildew/download.jpeg
#   inflating: Common_diseases/Powdery Mildew/istockphoto-1276445035-612x612.jpg
#   inflating: Common_diseases/Powdery Mildew/IMG_1507-2-rotated.webp
#   inflating: Common_diseases/Powdery Mildew/hgic_veg_PowderyMildew_cucurbits_1200.jpg
#   inflating: Common_diseases/Powdery Mildew/IMG-powdery-mildrew-banner-NA_CA_EN_V1.jpeg
#   inflating: Common_diseases/Powdery Mildew/255152-1600x1030-powdery-mildew-from-plants.jpg
#   inflating: Common_diseases/Powdery Mildew/Pumpkin-PM-mgt-expt_Bravo_Severe-PM-low_1991_scanned-slide.jpg
#   inflating: Common_diseases/Powdery Mildew/oidio-en-pepino.jpg
#   inflating: Common_diseases/Powdery Mildew/Soybean-Powdery-mildew-early-stage-Grau-Craig-Grau-and-University-of-Wisconsin-Teaching-Images-1300x975.jpg
#   inflating: Common_diseases/Powdery Mildew/IMG_6356.jpg
#   inflating: Common_diseases/Powdery Mildew/Powdery-mildew-on-field-peas-2.jpg
#   inflating: Common_diseases/Powdery Mildew/IMG_0702.jpg
#   inflating: Common_diseases/Powdery Mildew/dogwood-lg.gif
#   inflating: Common_diseases/Powdery Mildew/IG7-shutterstock_1036190317-scaled.jpg
#   inflating: Common_diseases/Powdery Mildew/Powdery-Mildew-Daren-Mueller-10-1300x1151.webp
#   inflating: Common_diseases/Powdery Mildew/powdery-mildew-main.png.webp
#   inflating: Common_diseases/Powdery Mildew/DTB_Powdery_Mildew_Disease.webp
#   inflating: Common_diseases/Powdery Mildew/DSC_0053-Adj-708X466.jpg
#   inflating: Common_diseases/Powdery Mildew/powdery-mildew-1402500-04b-87cab7453fc543fa96a593e5b8a436e7.jpg
#   inflating: Common_diseases/Powdery Mildew/hgic_trees and shurbs_powdery mildew_5535846-LGPT.jpg
#   inflating: Common_diseases/Powdery Mildew/Fig2powderymildewSGM_5788close.jpg
#   inflating: Common_diseases/Powdery Mildew/powdery_mildew_pumpkin_aiyura_6151.jpg
#   inflating: Common_diseases/Powdery Mildew/powdery-mildew-winter-squash.jpg
#   inflating: Common_diseases/Powdery Mildew/treating-powdery-mildew-plant-ac36e077ba4a4f6184824bd68483489c.jpg
#   inflating: Common_diseases/Powdery Mildew/rose_powdery_mildew.jpg
#   inflating: Common_diseases/Powdery Mildew/web_powderymildewandhowtocontrolit.jpg
#   inflating: Common_diseases/Powdery Mildew/Powdery-mildew-grapes.webp
#   inflating: Common_diseases/Powdery Mildew/Fig1PowderyMildew1SGM_5793.JPG
#   inflating: Common_diseases/Powdery Mildew/powdery-mildew-powdery-mildew-on-squash-leaf-shutterstock-com_13365.webp
#   inflating: Common_diseases/Powdery Mildew/Powdery-Mildew-Vegetables.jpg
#   inflating: Common_diseases/Powdery Mildew/How-to-Treat-Powdery-Mildew.webp
#   inflating: Common_diseases/Powdery Mildew/powdery-mildew-on-calendula.jpg
#   inflating: Common_diseases/Powdery Mildew/shutterstock_1806230311_1500x.webp
#   inflating: Common_diseases/Powdery Mildew/Powdery-Mildew4-1024x682.jpg
#   inflating: Common_diseases/Powdery Mildew/bigstock-powdery-mildew-on-norway-maple.jpg
#   inflating: Common_diseases/Powdery Mildew/sb-lc-diseases-header-powdery-mildew.webp
#   inflating: Common_diseases/Powdery Mildew/by-pest-powdery-mildew__64604.original.jpg
#   inflating: Common_diseases/Powdery Mildew/Powedery-Mildew-Feature.jpg
#   inflating: Common_diseases/Powdery Mildew/powderymildew.jpeg
#   inflating: Common_diseases/Powdery Mildew/powdery_mildew.jpg
#   inflating: Common_diseases/Powdery Mildew/white fluffy pustules_0.png
#   inflating: Common_diseases/Powdery Mildew/p1020011.jpg

# %%
learning_rate = 0.003
meta_step_size = 0.25

inner_batch_size = 25
eval_batch_size = 25

meta_iters = 1000
eval_iters = 5
inner_iters = 4

eval_interval = 1
train_shots = 20
shots = 5
classes = 6

# %%
class Dataset:
    # This class will facilitate the creation of a few-shot dataset
    # from the Omniglot dataset that can be sampled from quickly while also
    # allowing to create new labels at the same time.
    def __init__(self, training, ds=None):
        # Download the tfrecord files containing the omniglot data and convert to a
        # dataset.
        split = "train" if training else "test"
        if ds is None:
            ds = tfds.load("omniglot", split=split, as_supervised=True, shuffle_files=False)
        # Iterate over the dataset to get each individual image and its class,
        # and put that data into a dictionary.
        self.data = {}

        def extraction(image, label):
            # This function will shrink the Omniglot images to the desired size,
            # scale pixel values and convert the RGB image to grayscale
            image = tf.image.convert_image_dtype(image, tf.float32)
            # image = tf.image.rgb_to_grayscale(image)
            image = tf.image.resize(image, [64, 64])
            return image, label

        for image, label in ds.map(extraction):
            image = image.numpy()
            label = str(label.numpy())
            if label not in self.data:
                self.data[label] = []
            self.data[label].append(image)
        self.labels = list(self.data.keys())

    def get_mini_dataset(
        self, batch_size, repetitions, shots, num_classes, split=False
    ):
        temp_labels = np.zeros(shape=(num_classes * shots))
        temp_images = np.zeros(shape=(num_classes * shots, 64, 64, 3))
        if split:
            test_labels = np.zeros(shape=(num_classes))
            test_images = np.zeros(shape=(num_classes, 64, 64, 3))

        # Get a random subset of labels from the entire label set.
        label_subset = random.choices(self.labels, k=num_classes)
        for class_idx, class_obj in enumerate(label_subset):
            # Use enumerated index value as a temporary label for mini-batch in
            # few shot learning.
            temp_labels[class_idx * shots : (class_idx + 1) * shots] = class_idx
            # If creating a split dataset for testing, select an extra sample from each
            # label to create the test dataset.
            if split:
                test_labels[class_idx] = class_idx
                images_to_split = random.choices(
                    self.data[label_subset[class_idx]], k=shots + 1
                )
                test_images[class_idx] = images_to_split[-1]
                temp_images[
                    class_idx * shots : (class_idx + 1) * shots
                ] = images_to_split[:-1]
            else:
                # For each index in the randomly selected label_subset, sample the
                # necessary number of images.
                temp_images[
                    class_idx * shots : (class_idx + 1) * shots
                ] = random.choices(self.data[label_subset[class_idx]], k=shots)

        dataset = tf.data.Dataset.from_tensor_slices(
            (temp_images.astype(np.float32), temp_labels.astype(np.int32))
        )
        dataset = dataset.shuffle(100).batch(batch_size).repeat(repetitions)
        if split:
            return dataset, test_images, test_labels
        return dataset

# %%
def conv_bn(x, filter_size=64,kernel_size=3):
    x = layers.Conv2D(filters=filter_size, kernel_size=kernel_size, strides=2, padding="same")(x)
    x = layers.BatchNormalization()(x)
    return layers.ReLU()(x)


inputs = layers.Input(shape=(64, 64, 3))
x = conv_bn(inputs)
x = conv_bn(x)
x = conv_bn(x)
x = conv_bn(x)
x = layers.Flatten()(x)
outputs = layers.Dense(classes, activation="softmax")(x)
model = keras.Model(inputs=inputs, outputs=outputs)
model.compile()
optimizer = keras.optimizers.SGD(learning_rate=learning_rate)

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 64, 64, 3)]       0
#
#  conv2d_4 (Conv2D)           (None, 32, 32, 64)        1792
#
#  batch_normalization_4 (Bat  (None, 32, 32, 64)        256
#  chNormalization)
#
#  re_lu_4 (ReLU)              (None, 32, 32, 64)        0
#
#  conv2d_5 (Conv2D)           (None, 16, 16, 64)        36928
#
#  batch_normalization_5 (Bat  (None, 16, 16, 64)        256
#  chNormalization)
#
#  re_lu_5 (ReLU)              (None, 16, 16, 64)        0
#
#  conv2d_6 (Conv2D)           (None, 8, 8, 64)          36928
#
#  batch_normalization_6 (Bat  (None, 8, 8, 64)          256
#  chNormalization)
#
#  re_lu_6 (ReLU)              (None, 8, 8, 64)          0
#
#  conv2d_7 (Conv2D)           (None, 4, 4, 64)          36928
#
#  batch_normalization_7 (Bat  (None, 4, 4, 64)          256
#  chNormalization)
#
#  re_lu_7 (ReLU)              (None, 4, 4, 64)          0
#
#  flatten_1 (Flatten)         (None, 1024)              0
#
#  dense (Dense)               (None, 6)                 6150
#
# =================================================================
# Total params: 119750 (467.77 KB)
# Trainable params: 119238 (465.77 KB)
# Non-trainable params: 512 (2.00 KB)
# _________________________________________________________________

# %%
data_dir = "/content/Common_diseases"
img_height = 64
img_width = 64
batch_size = 1

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)

val_ds = tf.keras.utils.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)

train_ds = train_ds.unbatch()
train_ds = train_ds.map(lambda x, y: (tf.cast(x, tf.uint8), y))

val_ds = val_ds.unbatch()
val_ds = val_ds.map(lambda x, y: (tf.cast(x, tf.uint8), y))
# Out:
# Found 296 files belonging to 10 classes.
# Using 237 files for training.
# Found 296 files belonging to 10 classes.
# Using 59 files for validation.

# %%
labels_name = os.listdir(data_dir)
labels_name.sort()
labels_name[2]
# Out:
# 'Dog_vomit_slime_mold'

# %%
train_dataset = Dataset(training=True, ds=train_ds)
test_dataset = Dataset(training=False, ds=val_ds)

# %%
_, axarr = plt.subplots(nrows=5, ncols=3, figsize=(20, 20))

sample_keys = list(train_dataset.data.keys())

for a in range(5):
    for b in range(3):
        temp_image = train_dataset.data[sample_keys[a]][b]
        # temp_image = np.stack((temp_image[:, :, 0],) * 3, axis=2)
        # temp_image *= 255
        # temp_image = np.clip(temp_image, 0, 255).astype("uint8")
        if b == 1:
            axarr[a, b].set_title("Class : " + labels_name[int(sample_keys[a])])
        axarr[a, b].imshow(temp_image)
        axarr[a, b].xaxis.set_visible(False)
        axarr[a, b].yaxis.set_visible(False)
plt.show()

# %%
training = [0]
testing = [0]
for meta_iter in range(meta_iters):
    frac_done = meta_iter / meta_iters
    cur_meta_step_size = (1 - frac_done) * meta_step_size
    # Temporarily save the weights from the model.
    old_vars = model.get_weights()
    # Get a sample from the full dataset.
    mini_dataset = train_dataset.get_mini_dataset(
        inner_batch_size, inner_iters, train_shots, classes
    )
    for images, labels in mini_dataset:
        with tf.GradientTape() as tape:
            preds = model(images)
            loss = keras.losses.sparse_categorical_crossentropy(labels, preds)
        grads = tape.gradient(loss, model.trainable_weights)
        optimizer.apply_gradients(zip(grads, model.trainable_weights))
    new_vars = model.get_weights()
    # Perform SGD for the meta step.
    for var in range(len(new_vars)):
        new_vars[var] = old_vars[var] + (
            (new_vars[var] - old_vars[var]) * cur_meta_step_size
        )
    # After the meta-learning step, reload the newly-trained weights into the model.
    model.set_weights(new_vars)

    # Evaluation loop
    if meta_iter % eval_interval == 0:
        accuracies = []
        for dataset in (train_dataset, test_dataset):
            # Sample a mini dataset from the full dataset.
            train_set, test_images, test_labels = dataset.get_mini_dataset(
                eval_batch_size, eval_iters, shots, classes, split=True
            )
            old_vars = model.get_weights()
            # Train on the samples and get the resulting accuracies.
            for images, labels in train_set:
                with tf.GradientTape() as tape:
                    preds = model(images)
                    loss = keras.losses.sparse_categorical_crossentropy(labels, preds)
                grads = tape.gradient(loss, model.trainable_weights)
                optimizer.apply_gradients(zip(grads, model.trainable_weights))
            test_preds = model.predict(test_images)
            test_preds = tf.argmax(test_preds).numpy()
            num_correct = (test_preds == test_labels).sum()
            # Reset the weights after getting the evaluation accuracies.
            model.set_weights(old_vars)
            accuracies.append(num_correct / classes)
        if(accuracies[1] > testing[-1]):
          model.save_weights("./best_weights.h5", overwrite=True)
        training.append(accuracies[0])
        testing.append(accuracies[1])
        if meta_iter % 100 == 0:
            print(
                "batch %d: train=%f test=%f" % (meta_iter, accuracies[0], accuracies[1])
            )
# Out:
# WARNING:tensorflow:5 out of the last 5 calls to <function _BaseOptimizer._update_step_xla at 0x7ca950218c10> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 6 calls to <function _BaseOptimizer._update_step_xla at 0x7ca950218c10> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 0s 244ms/step
# 1/1 [==============================] - 0s 18ms/step
# batch 0: train=0.333333 test=0.333333
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 85ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 19ms/step
# batch 100: train=0.666667 test=0.833333
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# batch 200: train=0.333333 test=0.666667
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# batch 300: train=0.666667 test=0.666667
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# batch 400: train=1.000000 test=0.833333
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# ...
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 23ms/step
# batch 900: train=0.500000 test=0.833333
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step

# %%
window_length = 100
train_s = np.r_[
    training[window_length - 1 : 0 : -1],
    training,
    training[-1:-window_length:-1],
]
test_s = np.r_[
    testing[window_length - 1 : 0 : -1], testing, testing[-1:-window_length:-1]
]
w = np.hamming(window_length)
train_y = np.convolve(w / w.sum(), train_s, mode="valid")
test_y = np.convolve(w / w.sum(), test_s, mode="valid")

# Display the training accuracies.
x = np.arange(0, len(test_y), 1)
plt.plot(x, test_y, x, train_y)
plt.ylim(0, 1)
plt.legend(["test", "train"])
plt.grid()

train_set, test_images, test_labels = dataset.get_mini_dataset(
    eval_batch_size, eval_iters, shots, classes, split=True
)
for images, labels in train_set:
    with tf.GradientTape() as tape:
        preds = model(images)
        loss = keras.losses.sparse_categorical_crossentropy(labels, preds)
    grads = tape.gradient(loss, model.trainable_weights)
    optimizer.apply_gradients(zip(grads, model.trainable_weights))
test_preds = model.predict(test_images)
test_preds = tf.argmax(test_preds).numpy()

_, axarr = plt.subplots(nrows=1, ncols=5, figsize=(20, 20))

sample_keys = list(train_dataset.data.keys())

for i, ax in zip(range(5), axarr):
    temp_image = np.stack((test_images[i, :, :, 0],) * 3, axis=2)
    temp_image *= 255
    temp_image = np.clip(temp_image, 0, 255).astype("uint8")
    ax.set_title(
        "Label : {}, Prediction : {}".format(int(test_labels[i]), test_preds[i])
    )
    ax.imshow(temp_image, cmap="gray")
    ax.xaxis.set_visible(False)
    ax.yaxis.set_visible(False)
plt.show()
# Out:
# 1/1 [==============================] - 0s 28ms/step

# %%
train_y[-1]
# Out:
# 0.6354164670071119

# %%
test_y[-1]
# Out:
# 0.7312294735662144

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
